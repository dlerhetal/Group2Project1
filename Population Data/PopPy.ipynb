# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import csv
import os
pd.set_option('display.max_rows', None)
import datetime as dt

# %%
# Metro Population Source: https://www.statista.com/statistics/815653/nashville-metro-area-population/#:~:text=Nashville%2DDavidson%2DMurfreesboro%2DFranklin,area%20population%20U.S.%202010%2D2021&text=In%202021%2C%20the%20population%20of,was%20about%20two%20million%20people

# %%
Metro_Nash_Pop = pd.DataFrame({"Year": ["2018", "2019", "2020", "2021", "2022"],
                                "Population": [1906794, 1933455, 1995343, 2012476, 2049076]})
Metro_Nash_Pop
# Out:
#    Year  Population
# 0  2018     1906794
# 1  2019     1933455
# 2  2020     1995343
# 3  2021     2012476
# 4  2022     2049076

# %%
x_axis = Metro_Nash_Pop["Year"]
y_axis = Metro_Nash_Pop["Population"]
plt.bar(x_axis, y_axis)
plt.title("Metro Population by Year (2018-2022)")
plt.xlabel("Year")
plt.ylim(1750000, 2100000)
plt.ylabel("Population (per Million)")
# Out:
# Text(0, 0.5, 'Population (per Million)')
